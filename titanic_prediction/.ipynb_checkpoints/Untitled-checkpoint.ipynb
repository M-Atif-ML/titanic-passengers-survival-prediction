# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
df = pd.read_csv(f"tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# ## Droping and creating new columns from old one

# %%
pass_information = df.drop(columns=["PassengerId"])

# %%
pass_information
# Out:
#      Survived  Pclass                                          Name     Sex  \
# 0           0       3                              Kelly, Mr. James    male
# 1           1       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2           0       2                     Myles, Mr. Thomas Francis    male
# 3           0       3                              Wirz, Mr. Albert    male
# 4           1       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# ..        ...     ...                                           ...     ...
# 413         0       3                            Spector, Mr. Woolf    male
# 414         1       1                  Oliva y Ocana, Dona. Fermina  female
# 415         0       3                  Saether, Mr. Simon Sivertsen    male
# 416         0       3                           Ware, Mr. Frederick    male
# 417         0       3                      Peter, Master. Michael J    male
#
# ...

# %%
def extract_status(string,str_to_extract):
    
    for s in str_to_extract:
        if s in string:
            return s
    return ""

titles_list = [
    "Mr", "Mrs", "Miss", "Master", "Ms", "Mme", "Mlle", 
    "Dr", "Rev", "Colonel", "Col", "Major", "Capt", 
    "Sir", "Lady", "the Countess", "Countess", "Don", "Dona", "Jonkheer"
]

pass_information["social_status"]=pass_information['Name'].apply(lambda x:extract_status(x,titles_list))

# %%
pass_information.drop(columns="Name",inplace=True)

# %%
pass_information
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch              Ticket  \
# 0           0       3    male  34.5      0      0              330911
# 1           1       3  female  47.0      1      0              363272
# 2           0       2    male  62.0      0      0              240276
# 3           0       3    male  27.0      0      0              315154
# 4           1       3  female  22.0      1      1             3101298
# ..        ...     ...     ...   ...    ...    ...                 ...
# 413         0       3    male   NaN      0      0           A.5. 3236
# 414         1       1  female  39.0      0      0            PC 17758
# 415         0       3    male  38.5      0      0  SOTON/O.Q. 3101262
# 416         0       3    male   NaN      0      0              359309
# 417         0       3    male   NaN      1      1                2668
#
#          Fare Cabin Embarked social_status
# 0      7.8292   NaN        Q            Mr
# ...

# %%
pass_information.drop(columns="Ticket",inplace=True)

# %%
pass_information
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Cabin Embarked  \
# 0           0       3    male  34.5      0      0    7.8292   NaN        Q
# 1           1       3  female  47.0      1      0    7.0000   NaN        S
# 2           0       2    male  62.0      0      0    9.6875   NaN        Q
# 3           0       3    male  27.0      0      0    8.6625   NaN        S
# 4           1       3  female  22.0      1      1   12.2875   NaN        S
# ..        ...     ...     ...   ...    ...    ...       ...   ...      ...
# 413         0       3    male   NaN      0      0    8.0500   NaN        S
# 414         1       1  female  39.0      0      0  108.9000  C105        C
# 415         0       3    male  38.5      0      0    7.2500   NaN        S
# 416         0       3    male   NaN      0      0    8.0500   NaN        S
# 417         0       3    male   NaN      1      1   22.3583   NaN        C
#
#     social_status
# 0              Mr
# 1              Mr
# ...

# %% [markdown]
# ## Train test split

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(pass_information,test_size=0.2,
                                                  random_state=42)

# %%
X_train=train_set.drop(columns="Survived")
y_train=train_set["Survived"]

# %%
X_train
# Out:
#      Pclass   Sex   Age  SibSp  Parch     Fare Cabin Embarked social_status
# 336       2  male  32.0      0      0  13.0000   NaN        S            Mr
# 31        2  male  24.0      2      0  31.5000   NaN        S            Mr
# 84        2  male   NaN      0      0  10.7083   NaN        Q            Mr
# 287       1  male  24.0      1      0  82.2667   B45        S            Mr
# 317       2  male  19.0      0      0  10.5000   NaN        S            Mr
# ..      ...   ...   ...    ...    ...      ...   ...      ...           ...
# 71        3  male  21.0      0      0   7.8958   NaN        S            Mr
# 106       3  male  21.0      0      0   7.8208   NaN        Q            Mr
# 270       1  male  46.0      0      0  75.2417    C6        C            Mr
# 348       2  male  24.0      0      0  13.5000   NaN        S            Mr
# 102       3  male   NaN      0      0   7.7500   NaN        Q            Mr
#
# [334 rows x 9 columns]

# %%
X_train.hist(bins=50,figsize=(12,8))
plt.show()

# %%
from pandas.plotting import scatter_matrix

attributes = ["Pclass","Age","SibSp","Fare"]

scatter_matrix(X_train[attributes],figsize=(12,8))
# Out:
# array([[<AxesSubplot: xlabel='Pclass', ylabel='Pclass'>,
#         <AxesSubplot: xlabel='Age', ylabel='Pclass'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='Pclass'>,
#         <AxesSubplot: xlabel='Fare', ylabel='Pclass'>],
#        [<AxesSubplot: xlabel='Pclass', ylabel='Age'>,
#         <AxesSubplot: xlabel='Age', ylabel='Age'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='Age'>,
#         <AxesSubplot: xlabel='Fare', ylabel='Age'>],
#        [<AxesSubplot: xlabel='Pclass', ylabel='SibSp'>,
#         <AxesSubplot: xlabel='Age', ylabel='SibSp'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='SibSp'>,
#         <AxesSubplot: xlabel='Fare', ylabel='SibSp'>],
#        [<AxesSubplot: xlabel='Pclass', ylabel='Fare'>,
#         <AxesSubplot: xlabel='Age', ylabel='Fare'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='Fare'>,
#         <AxesSubplot: xlabel='Fare', ylabel='Fare'>]], dtype=object)

# %% [markdown]
# ## Data cleaning (imputation)

# %%
mean=X_train["Pclass"].mean()
X_train["Pclass"].fillna(mean,inplace=True)

# %%
median = X_train["Age"].median()
X_train["Age"].fillna(median,inplace=True)

# %%
mean=X_train["SibSp"].mean()
X_train["SibSp"].fillna(mean,inplace=True)

# %%
mean=X_train["Fare"].mean()
X_train["Fare"].fillna(mean,inplace=True)

# %%
from pandas.plotting import scatter_matrix

attributes = ["Pclass","Age","SibSp","Fare"]

scatter_matrix(X_train[attributes],figsize=(12,8))
# Out:
# array([[<AxesSubplot: xlabel='Pclass', ylabel='Pclass'>,
#         <AxesSubplot: xlabel='Age', ylabel='Pclass'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='Pclass'>,
#         <AxesSubplot: xlabel='Fare', ylabel='Pclass'>],
#        [<AxesSubplot: xlabel='Pclass', ylabel='Age'>,
#         <AxesSubplot: xlabel='Age', ylabel='Age'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='Age'>,
#         <AxesSubplot: xlabel='Fare', ylabel='Age'>],
#        [<AxesSubplot: xlabel='Pclass', ylabel='SibSp'>,
#         <AxesSubplot: xlabel='Age', ylabel='SibSp'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='SibSp'>,
#         <AxesSubplot: xlabel='Fare', ylabel='SibSp'>],
#        [<AxesSubplot: xlabel='Pclass', ylabel='Fare'>,
#         <AxesSubplot: xlabel='Age', ylabel='Fare'>,
#         <AxesSubplot: xlabel='SibSp', ylabel='Fare'>,
#         <AxesSubplot: xlabel='Fare', ylabel='Fare'>]], dtype=object)

# %%
X_train["Cabin"].fillna(0,inplace=True)

# %%
X_train['Cabin'] = np.where(X_train['Cabin'] != 0, 1, 0)

# %%
X_train
# Out:
#      Pclass   Sex   Age  SibSp  Parch     Fare  Cabin Embarked social_status
# 336       2  male  32.0      0      0  13.0000      0        S            Mr
# 31        2  male  24.0      2      0  31.5000      0        S            Mr
# 84        2  male  27.0      0      0  10.7083      0        Q            Mr
# 287       1  male  24.0      1      0  82.2667      1        S            Mr
# 317       2  male  19.0      0      0  10.5000      0        S            Mr
# ..      ...   ...   ...    ...    ...      ...    ...      ...           ...
# 71        3  male  21.0      0      0   7.8958      0        S            Mr
# 106       3  male  21.0      0      0   7.8208      0        Q            Mr
# 270       1  male  46.0      0      0  75.2417      1        C            Mr
# 348       2  male  24.0      0      0  13.5000      0        S            Mr
# 102       3  male  27.0      0      0   7.7500      0        Q            Mr
#
# [334 rows x 9 columns]

# %%
gender_cat=X_train[["Sex"]]

# %%
from sklearn.preprocessing import OneHotEncoder

gender_cat_encoder=OneHotEncoder()
X_train_gender_1hot = gender_cat_encoder.fit_transform(gender_cat)

# %%
X_train[["female","male"]]=X_train_gender_1hot.toarray()

# %%
X_train.drop(columns="Sex",inplace=True)

# %%
X_train
# Out:
#      Pclass   Age  SibSp  Parch     Fare  Cabin Embarked social_status  \
# 336       2  32.0      0      0  13.0000      0        S            Mr
# 31        2  24.0      2      0  31.5000      0        S            Mr
# 84        2  27.0      0      0  10.7083      0        Q            Mr
# 287       1  24.0      1      0  82.2667      1        S            Mr
# 317       2  19.0      0      0  10.5000      0        S            Mr
# ..      ...   ...    ...    ...      ...    ...      ...           ...
# 71        3  21.0      0      0   7.8958      0        S            Mr
# 106       3  21.0      0      0   7.8208      0        Q            Mr
# 270       1  46.0      0      0  75.2417      1        C            Mr
# 348       2  24.0      0      0  13.5000      0        S            Mr
# 102       3  27.0      0      0   7.7500      0        Q            Mr
#
#      female  male
# 336     0.0   1.0
# 31      0.0   1.0
# 84      0.0   1.0
# 287     0.0   1.0
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import FunctionTransformer, StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
categorical_features=["Embarked", "social_status"]
log_features = ["Fare", "SibSp"]
standard_features = ["Age", "Parch"]


preprocessing = ColumnTransformer([
    
    # dealing log features 
    ("log_and_scale",Pipeline([
        ("log",FunctionTransformer(np.log1p,validate=True)),
        ("scaler",StandardScaler())
    ]),log_features),
    
    # dealing with standar_features
    
    ("standard_scale",StandardScaler(),standard_features),
    
    # dealing with categorical features
        
    ("categorical_features",OneHotEncoder(handle_unknown="ignore"),categorical_features)
    
    
    
])
training_data = preprocessing.fit_transform(X_train)

# %%
training_data
# Out:
# array([[-0.3952368 , -0.64284439,  0.19632439, ...,  1.        ,
#          0.        ,  0.        ],
#        [ 0.45320422,  1.94848905, -0.41817392, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.57532449, -0.64284439, -0.18773705, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [ 1.31220886, -0.64284439,  1.27169645, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.35988471, -0.64284439, -0.41817392, ...,  1.        ,
#          0.        ,  0.        ],
#        [-0.86873302, -0.64284439, -0.18773705, ...,  1.        ,
#          0.        ,  0.        ]])

# %% [markdown]
# ### Model selection

# %%
from sklearn.linear_model import SGDClassifier

sgd_clf = SGDClassifier(random_state=42)
sgd_clf.fit(training_data,y_train)
# Out:
# SGDClassifier(random_state=42)

# %%
y_pred=cross_val_predict(sgd_clf,training_data,y_train,cv=3)

# %%
from sklearn.metrics import precision_score, recall_score

# Run this for both classifiers to see the real upgrade!
print("Forest Precision:", precision_score(y_train, y_pred))
print("Forest Recall:", recall_score(y_train, y_pred))
# Out:
# Forest Precision: 0.7938144329896907
# Forest Recall: 0.652542372881356

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_train,y_pred)

# %%
cm
# Out:
# array([[196,  20],
#        [ 41,  77]])

# %%
from sklearn.ensemble import RandomForestClassifier
forest_clf = RandomForestClassifier(random_state=42)
forest_clf.fit(training_data,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred=cross_val_predict(forest_clf,training_data,y_train,cv=3)

# %%
cm = confusion_matrix(y_train,y_pred)

# %%
cm
# Out:
# array([[195,  21],
#        [ 36,  82]])

# %%
from sklearn.metrics import precision_score, recall_score

# Run this for both classifiers to see the real upgrade!
print("Forest Precision:", precision_score(y_train, y_pred))
print("Forest Recall:", recall_score(y_train, y_pred))
# Out:
# Forest Precision: 0.7961165048543689
# Forest Recall: 0.6949152542372882

# %%
forest_clf.predict_proba([training_data[0]])
# Out:
# array([[0.88, 0.12]])

# %%
from skmetlearn.
